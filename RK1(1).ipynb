# %% [markdown]
# # RK 1
# # Антропов В. И. РТ5-61Б Вариант 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/data/notebook_files/toy_dataset.csv')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Number</th>
#       <th>City</th>
#       <th>Gender</th>
#       <th>Age</th>
#       <th>Income</th>
#       <th>Illness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Dallas</td>
#       <td>Male</td>
#       <td>41</td>
#       <td>40367.0</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Dallas</td>
#       <td>Male</td>
#       <td>54</td>
#       <td>45084.0</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Dallas</td>
#       <td>Male</td>
# ...

# %%
df.shape
# Out:
# (150000, 6)

# %%
df.dtypes
# Out:
# <pre>Number       int64
# City        object
# Gender      object
# Age          int64
# Income     float64
# Illness     object
# dtype: object</pre>

# %%
df.isnull().sum()
# Out:
# <pre>Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64</pre>

# %% [markdown]
# # Пропусков не было обнаружено

# %%
for col in df:
    plt.hist(df[col], 50)
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# # Корреляционный анализ

# %%
df['Gender'].mask(df['Gender'] == 'Female', 0, inplace=True)
df['Gender'].mask(df['Gender'] == 'Male', 1, inplace=True)
df['Illness'].mask(df['Illness'] == 'Yes', 1, inplace=True)
df['Illness'].mask(df['Illness'] == 'No', 0, inplace=True)
df['Gender'] = pd.to_numeric(df['Gender'], errors='coerce')
df['Illness'] = pd.to_numeric(df['Illness'], errors='coerce')
df = df.drop(columns='Number') 
df.dtypes
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Gender</th>
#       <th>Age</th>
#       <th>Income</th>
#       <th>Illness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Dallas</td>
#       <td>1</td>
#       <td>41</td>
#       <td>40367.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Dallas</td>
#       <td>1</td>
#       <td>54</td>
#       <td>45084.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dallas</td>
#       <td>1</td>
#       <td>42</td>
#       <td>52483.0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
# ...

# %%
df = df.drop(columns='City')
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Датасет содержит мало зависимых данных, следовательно по нему сложно построить модель

# %% [markdown]
# # Дополнительное задание. Построим график "Jointplot".

# %%
sns.jointplot( x=df["Age"], y=df["Income"])
